# %% [markdown]
# <a href="https://colab.research.google.com/github/anasarshad7677-netizen/Complete-ML-repo/blob/main/6_EDA_using_bi_and_multivariate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df =sns.load_dataset('tips')

# %% [markdown]
# 1:scatterplot ( numerical - numerical)

# %%
sns.scatterplot(
    data = df ,
    x = 'total_bill',
    y = 'tip',
)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(
    data = df ,
    x = 'total_bill',
    y = 'tip',
    hue = 'sex',
    style = 'smoker',

)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# bar plot ( numerical - categoral )

# %%
df =sns.load_dataset('titanic')
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df = sns.load_dataset('titanic')
sns.barplot(
    data = df,
    x = 'pclass',
    y = 'fare',
    hue = 'sex'
)
# Out:
# <Axes: xlabel='pclass', ylabel='fare'>

# %%
df = sns.load_dataset('titanic')
sns.barplot(
    data = df,
    x = 'pclass',
    y = 'age',
    hue = 'sex'
)
# Out:
# <Axes: xlabel='pclass', ylabel='age'>

# %% [markdown]
# boxplot ( numerical - categorical)

# %%
sns.boxplot(
    data = df,
    x='sex',
    y ='age',
    hue='survived'
)
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.kdeplot(
    data=df[df['survived']==0],
    x = 'age'
)

sns.kdeplot(
    data = df[df['survived']==1],
    x = 'age'
)
# Out:
# <Axes: xlabel='age', ylabel='Density'>

# %% [markdown]
# heatMap ( categorical - categorical )

# %%
sns.heatmap(pd.crosstab(df['pclass'],df['survived']))
# Out:
# <Axes: xlabel='survived', ylabel='pclass'>

# %%
df.groupby('pclass')['survived'].mean().plot(kind='bar')
# Out:
# <Axes: xlabel='pclass'>

# %%
df.groupby('sex')['survived'].mean().plot(kind='bar')
# Out:
# <Axes: xlabel='sex'>

# %%
df.groupby('embarked')['survived'].mean().plot(kind='bar')
# Out:
# <Axes: xlabel='embarked'>

# %%
df =sns.pairplot(df)

# %%
df =sns.load_dataset('flights')

# %%
df.groupby('year')['passengers'].sum().plot()
# Out:
# <Axes: xlabel='year'>
